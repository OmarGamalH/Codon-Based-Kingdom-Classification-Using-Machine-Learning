# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import f1_score , confusion_matrix , classification_report
from sklearn.svm import SVC
import os
import pickle as pk
import seaborn as sb
import matplotlib.pyplot as plt

# %%
CURR_DIR = os.getcwd()
DATA_DIR = os.path.join(CURR_DIR , 'drive' , 'MyDrive' , 'Codon_Usage_dataset')
PCA_FILE_NAME = "pca_results.csv"
PCA_PATH = os.path.join(DATA_DIR , PCA_FILE_NAME)
OUTPUT_PATH = DATA_DIR

# %%
pca_data = pd.read_csv(PCA_PATH)
pca_data
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0      5.999607 -0.110518  3.624183 -2.226701  0.959577  1.476934 -0.252336
# 1      5.585957 -0.273068  4.076570 -1.804301 -0.747029  1.178151 -1.544513
# 2     -0.274695 -2.535389  1.838187 -2.299159  0.415666 -0.364983 -0.243076
# 3     -1.616704 -2.118830  1.556229 -1.328989 -0.272819  2.135633 -0.070702
# 4     -0.786983 -4.976234  0.499870  0.221165  0.152280  0.011056  0.056625
# ...         ...       ...       ...       ...       ...       ...       ...
# 13005  1.488028 -1.285673  2.506186 -2.594555 -0.033034  0.214512 -1.256892
# 13006  0.942722  7.180218  0.446369  0.270972 -0.215830 -0.172294 -1.108029
# 13007  1.091028  8.259384  0.200550  0.444341 -0.787122 -1.463038 -1.210190
# 13008  2.432261 -1.167826  1.805895 -1.741807  0.323634  0.848070 -0.196708
# 13009  0.335443  6.675303  0.278048  0.355334  0.076834  0.100802 -0.855018
#
#             PC8       PC9      PC10  ...      PC17      PC18      PC19  \
# 0     -0.708389 -0.505336 -1.730777  ... -0.872885 -1.447775  0.054360
# 1     -1.309988 -0.412640 -1.676344  ... -0.076676 -0.045823  0.511744
# 2      0.255400  0.459756  0.439171  ... -0.981680  0.143479 -0.710796
# 3     -0.155886  0.617887 -1.513015  ... -0.295139  0.451240 -0.533989
# 4     -0.583426 -0.031140 -0.958820  ... -0.499746 -0.530838 -0.699213
# ...         ...       ...       ...  ...       ...       ...       ...
# 13005  0.289318 -0.245747  1.154231  ...  1.379061 -0.929496 -0.105079
# 13006  0.695637  0.060012 -0.376058  ... -0.596185 -0.247884 -0.328866
# 13007  1.284691  0.555139 -0.474701  ... -1.019093  0.094483 -0.018001
# 13008  0.921848 -0.755293  0.161436  ...  0.131042 -0.313954 -0.500590
# 13009 -0.191240  0.110455 -0.388821  ... -0.909267 -0.763996 -0.193308
#
#            PC20      PC21      PC22      PC23      PC24      PC25  Kingdom
# 0     -0.089393 -0.424739 -0.837635 -0.514593  0.471557 -0.290105      vrl
# 1     -0.339438 -0.561600 -0.051212  0.962530 -0.322449  0.141626      vrl
# 2     -0.968506 -0.507073  0.023495  0.094500  0.387273  0.200335      vrl
# 3      0.252502 -1.034724  0.694537 -0.262238  0.909396  0.805527      vrl
# 4      0.730259  0.873118  0.765742  0.135460 -0.745189 -0.348492      vrl
# ...         ...       ...       ...       ...       ...       ...      ...
# 13005  0.286591  0.384934  0.145774  0.235111  0.525128  1.269992      mam
# 13006  0.793225 -0.236648 -0.166733 -0.340554  0.262782  0.271341      mam
# 13007  0.777968  0.648920 -0.237344  0.283081 -0.044386  0.123673      mam
# 13008 -0.105909  0.307786  0.283756 -0.037844  0.212148 -0.208889      mam
# 13009  0.933620 -0.336531 -0.366980 -0.382357 -0.200651 -0.040829      mam
#
# [13010 rows x 26 columns]

# %%
X , Y = pca_data.iloc[: , :-1] , pca_data.iloc[: , -1]
X , Y
# Out:
# (            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
#  0      5.999607 -0.110518  3.624183 -2.226701  0.959577  1.476934 -0.252336
#  1      5.585957 -0.273068  4.076570 -1.804301 -0.747029  1.178151 -1.544513
#  2     -0.274695 -2.535389  1.838187 -2.299159  0.415666 -0.364983 -0.243076
#  3     -1.616704 -2.118830  1.556229 -1.328989 -0.272819  2.135633 -0.070702
#  4     -0.786983 -4.976234  0.499870  0.221165  0.152280  0.011056  0.056625
#  ...         ...       ...       ...       ...       ...       ...       ...
#  13005  1.488028 -1.285673  2.506186 -2.594555 -0.033034  0.214512 -1.256892
#  13006  0.942722  7.180218  0.446369  0.270972 -0.215830 -0.172294 -1.108029
#  13007  1.091028  8.259384  0.200550  0.444341 -0.787122 -1.463038 -1.210190
#  13008  2.432261 -1.167826  1.805895 -1.741807  0.323634  0.848070 -0.196708
#  13009  0.335443  6.675303  0.278048  0.355334  0.076834  0.100802 -0.855018
#
#              PC8       PC9      PC10  ...      PC16      PC17      PC18  \
#  0     -0.708389 -0.505336 -1.730777  ... -0.394933 -0.872885 -1.447775
#  1     -1.309988 -0.412640 -1.676344  ... -0.029452 -0.076676 -0.045823
#  2      0.255400  0.459756  0.439171  ... -1.278238 -0.981680  0.143479
#  3     -0.155886  0.617887 -1.513015  ...  0.356432 -0.295139  0.451240
#  4     -0.583426 -0.031140 -0.958820  ... -0.770759 -0.499746 -0.530838
#  ...         ...       ...       ...  ...       ...       ...       ...
#  13005  0.289318 -0.245747  1.154231  ...  0.672860  1.379061 -0.929496
#  13006  0.695637  0.060012 -0.376058  ...  0.205176 -0.596185 -0.247884
#  13007  1.284691  0.555139 -0.474701  ...  0.429481 -1.019093  0.094483
#  13008  0.921848 -0.755293  0.161436  ...  1.083592  0.131042 -0.313954
#  13009 -0.191240  0.110455 -0.388821  ...  0.414913 -0.909267 -0.763996
#
#             PC19      PC20      PC21      PC22      PC23      PC24      PC25
#  0      0.054360 -0.089393 -0.424739 -0.837635 -0.514593  0.471557 -0.290105
#  1      0.511744 -0.339438 -0.561600 -0.051212  0.962530 -0.322449  0.141626
#  2     -0.710796 -0.968506 -0.507073  0.023495  0.094500  0.387273  0.200335
#  3     -0.533989  0.252502 -1.034724  0.694537 -0.262238  0.909396  0.805527
#  4     -0.699213  0.730259  0.873118  0.765742  0.135460 -0.745189 -0.348492
#  ...         ...       ...       ...       ...       ...       ...       ...
#  13005 -0.105079  0.286591  0.384934  0.145774  0.235111  0.525128  1.269992
#  13006 -0.328866  0.793225 -0.236648 -0.166733 -0.340554  0.262782  0.271341
#  13007 -0.018001  0.777968  0.648920 -0.237344  0.283081 -0.044386  0.123673
#  13008 -0.500590 -0.105909  0.307786  0.283756 -0.037844  0.212148 -0.208889
#  13009 -0.193308  0.933620 -0.336531 -0.366980 -0.382357 -0.200651 -0.040829
#
#  [13010 rows x 25 columns],
#  0        vrl
#  1        vrl
#  2        vrl
#  3        vrl
#  4        vrl
#          ...
#  13005    mam
#  13006    mam
#  13007    mam
#  13008    mam
#  13009    mam
#  Name: Kingdom, Length: 13010, dtype: object)

# %%
X_train, X_test , y_train, y_test = train_test_split(X , Y , test_size = 0.2 ,  stratify = Y , random_state = 42)

# %%
model_grid_serach = SVC()
param_grid = {'C' : np.linspace(0.1 , 1 , 5) , 'kernel' : ['linear', 'poly', 'rbf', 'sigmoid']}
grid_search = GridSearchCV(model_grid_serach , param_grid=param_grid , cv = 5 , scoring='f1_macro' , n_jobs = -1)


grid_search.fit(X_train.to_numpy() , y_train.to_numpy())
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': array([0.1  , 0.325, 0.55 , 0.775, 1.   ]),
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='f1_macro')

# %%
print(f"Best Parameters : {grid_search.best_params_}")
# Out:
# Best Parameters : {'C': np.float64(1.0), 'kernel': 'rbf'}

# %%
model = SVC(**grid_search.best_params_ , probability = True)

model.fit(X_train , y_train)
# Out:
# SVC(C=np.float64(1.0), probability=True)

# %%
y_pred_train = model.predict(X_train)
y_pred_test  = model.predict(X_test)
f1_train = f1_score(y_train , y_pred_train , average = 'macro')
f1_test = f1_score(y_test , y_pred_test , average = 'macro')

# %%
print(f"""
    F1-Score of training: {f1_train}

    F1-Score of test: {f1_test}
""")
# Out:
#     F1-Score of training: 0.896738669125934
#
#     F1-Score of test: 0.8421245856690995

# %%
def save_model(saved_model , filename):
    with open(f"{filename}.pkl" , "wb") as f:
        pk.dump(saved_model , f)

def load_model(filename):
    with open(f"{filename}.pkl" , "rb") as f:
        saved_model = pk.load(f)
    return saved_model

# %%
save_model(model , os.path.join(OUTPUT_PATH , 'SVM'))

# %%
y_labels = list(set(Y))
cm = confusion_matrix(y_test , y_pred_test , labels = y_labels)

# %%
heat_map = sb.heatmap(cm , annot = True , fmt = '.0f' , xticklabels = y_labels , yticklabels = y_labels)
heat_map.set_title("SVM Confusion matrix")
heat_map.set_xlabel("predicted")
heat_map.set_ylabel("Actual")
plt.show()

# %%
print(classification_report(y_test , y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          arc       0.83      0.40      0.54        25
#          bct       0.91      0.97      0.94       584
#          inv       0.88      0.81      0.84       269
#          mam       0.95      0.93      0.94       193
#          phg       0.96      0.50      0.66        44
#          pln       0.93      0.93      0.93       505
#          vrl       0.92      0.96      0.94       567
#          vrt       0.96      0.94      0.95       415
#
#     accuracy                           0.92      2602
#    macro avg       0.92      0.81      0.84      2602
# weighted avg       0.92      0.92      0.92      2602

# %%
PRE_PCA_FILE_NAME = "Pre_PCA.csv"
PRE_PCA_PATH = os.path.join(DATA_DIR , PRE_PCA_FILE_NAME)
pre_pca_data = pd.read_csv(PRE_PCA_PATH)

# %%
X , Y = pre_pca_data.iloc[: , 1:] ,  pre_pca_data.iloc[: , 0]

# %%
X_train, X_test , y_train, y_test = train_test_split(X , Y , test_size = 0.2 ,  stratify = Y , random_state = 42)

# %%
X_train
# Out:
#            UUU      UUC      UUA      UUG      CUU      CUC      CUA      CUG  \
# 2123   0.01618  0.01044  0.01647  0.02117  0.01303  0.00733  0.01737  0.01800
# 5893   0.03310  0.00999  0.04310  0.00687  0.02186  0.00500  0.01124  0.00125
# 2788   0.00866  0.02087  0.00670  0.01300  0.00945  0.01418  0.00827  0.01497
# 12587  0.01899  0.02804  0.00479  0.01207  0.01295  0.02839  0.00408  0.03673
# 12328  0.01837  0.04592  0.01799  0.00000  0.01837  0.03661  0.08078  0.00478
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 8350   0.06054  0.02212  0.05106  0.01165  0.03466  0.01817  0.00701  0.00820
# 1467   0.02395  0.04940  0.02395  0.02769  0.03668  0.00524  0.01048  0.03593
# 3078   0.02815  0.01404  0.03063  0.02179  0.01733  0.00599  0.00782  0.00958
# 7125   0.04743  0.02964  0.02569  0.02964  0.02964  0.00741  0.02470  0.01136
# 11533  0.00982  0.02736  0.00272  0.00908  0.00815  0.02192  0.00247  0.04471
#
#            AUU      AUC  ...      CGG      AGA      AGG      GAU      GAC  \
# 2123   0.01526  0.01436  ...  0.00379  0.02397  0.01794  0.02621  0.02108
# 5893   0.04185  0.00874  ...  0.00125  0.02124  0.00375  0.03435  0.00812
# 2788   0.01378  0.02166  ...  0.01733  0.00985  0.01221  0.02481  0.04017
# 12587  0.01437  0.03070  ...  0.01012  0.00870  0.01349  0.01171  0.02591
# 12328  0.02969  0.04290  ...  0.00000  0.00252  0.00000  0.00881  0.01912
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 8350   0.04898  0.01659  ...  0.00040  0.01175  0.00188  0.02034  0.00780
# 1467   0.01946  0.02844  ...  0.00898  0.01796  0.01198  0.02395  0.01796
# 3078   0.03772  0.02010  ...  0.00387  0.00892  0.00234  0.03648  0.02113
# 7125   0.04150  0.01038  ...  0.00791  0.01186  0.00791  0.02372  0.00593
# 11533  0.01075  0.03279  ...  0.00661  0.01050  0.01235  0.01513  0.03520
#
#            GAA      GAG      UAA      UAG      UGA
# 2123   0.03986  0.03252  0.00136  0.00067  0.00057
# 5893   0.03560  0.00937  0.00187  0.00000  0.00000
# 2788   0.02521  0.02915  0.00000  0.00079  0.00000
# 12587  0.01739  0.03656  0.00124  0.00213  0.00444
# 12328  0.01195  0.00113  0.00000  0.00013  0.02869
# ...        ...      ...      ...      ...      ...
# 8350   0.02607  0.00662  0.00346  0.00020  0.00059
# 1467   0.02994  0.02395  0.00299  0.00000  0.00299
# 3078   0.04671  0.01930  0.00285  0.00080  0.00117
# 7125   0.03953  0.01976  0.00000  0.00000  0.00198
# 11533  0.01433  0.04984  0.00062  0.00068  0.00167
#
# [10406 rows x 64 columns]

# %%
model_grid_serach = SVC()
param_grid = {'C' : np.linspace(0.1 , 1 , 5) , 'kernel' : ['linear', 'poly', 'rbf', 'sigmoid']}
grid_search = GridSearchCV(model_grid_serach , param_grid=param_grid , cv = 5 , scoring='f1_macro' , n_jobs = -1)


grid_search.fit(X_train.to_numpy() , y_train.to_numpy())
# Out:
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': array([0.1  , 0.325, 0.55 , 0.775, 1.   ]),
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='f1_macro')

# %%
grid_search.best_params_
# Out:
# {'C': np.float64(0.775), 'kernel': 'poly'}

# %%
model = SVC(**grid_search.best_params_ , probability = True)

model.fit(X_train , y_train)
# Out:
# SVC(C=np.float64(0.775), kernel='poly', probability=True)

# %%
y_pred_train = model.predict(X_train)
y_pred_test  = model.predict(X_test)
f1_train = f1_score(y_train , y_pred_train , average = 'macro')
f1_test = f1_score(y_test , y_pred_test , average = 'macro')

# %%
print(f"""
    F1-Score of training: {f1_train}

    F1-Score of test: {f1_test}
""")
# Out:
#     F1-Score of training: 0.9631523889353563
#
#     F1-Score of test: 0.9148801115229213

# %%
y_labels = list(set(Y))
cm = confusion_matrix(y_test , y_pred_test , labels = y_labels)

# %%
heat_map = sb.heatmap(cm , annot = True , fmt = '.0f' , xticklabels = y_labels , yticklabels = y_labels)
heat_map.set_title("SVM Confusion matrix before PCA")
heat_map.set_xlabel("predicted")
heat_map.set_ylabel("Actual")
plt.show()

# %%
print(classification_report(y_test , y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          arc       0.78      0.84      0.81        25
#          bct       0.96      0.98      0.97       584
#          inv       0.92      0.86      0.89       269
#          mam       0.98      0.96      0.97       193
#          phg       0.94      0.70      0.81        44
#          pln       0.96      0.95      0.95       505
#          vrl       0.94      0.98      0.96       566
#          vrt       0.97      0.97      0.97       416
#
#     accuracy                           0.95      2602
#    macro avg       0.93      0.90      0.91      2602
# weighted avg       0.95      0.95      0.95      2602

# %%
save_model(model , os.path.join(OUTPUT_PATH , 'Before_SVM'))
